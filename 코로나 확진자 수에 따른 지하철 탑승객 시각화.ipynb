# %%
import pandas as pd
corona=pd.read_csv('./서울시 코로나19 확진자 현황.csv')

# %%
# 서울시 일일 확진자 데이터 전처리
freq = corona.groupby(['date']).count()
corona_seoul=freq['����']
corona_seoul=corona_seoul.rename('corona')
coro_seoul=corona_seoul[73:523]

# %%
# 수도권 지하철 일일 승하차 인원 수 데이터 읽기
subway_1901=pd.read_csv('./CARD_SUBWAY_MONTH_201901.csv')
subway_1902=pd.read_csv('./CARD_SUBWAY_MONTH_201902.csv')
subway_1903=pd.read_csv('./CARD_SUBWAY_MONTH_201903.csv')
subway_1904=pd.read_csv('./CARD_SUBWAY_MONTH_201904.csv')
subway_1905=pd.read_csv('./CARD_SUBWAY_MONTH_201905.csv')
subway_1906=pd.read_csv('./CARD_SUBWAY_MONTH_201906.csv')
subway_1907=pd.read_csv('./CARD_SUBWAY_MONTH_201907.csv')
subway_1908=pd.read_csv('./CARD_SUBWAY_MONTH_201908.csv')
subway_1909=pd.read_csv('./CARD_SUBWAY_MONTH_201909.csv')
subway_1910=pd.read_csv('./CARD_SUBWAY_MONTH_201910.csv')
subway_1911=pd.read_csv('./CARD_SUBWAY_MONTH_201911.csv')
subway_1912=pd.read_csv('./CARD_SUBWAY_MONTH_201912.csv')
subway_2001=pd.read_csv('./CARD_SUBWAY_MONTH_202001.csv')
subway_2002=pd.read_csv('./CARD_SUBWAY_MONTH_202002.csv')
subway_2003=pd.read_csv('./CARD_SUBWAY_MONTH_202003.csv')
subway_2004=pd.read_csv('./CARD_SUBWAY_MONTH_202004.csv')
subway_2005=pd.read_csv('./CARD_SUBWAY_MONTH_202005.csv')
subway_2006=pd.read_csv('./CARD_SUBWAY_MONTH_202006.csv')
subway_2007=pd.read_csv('./CARD_SUBWAY_MONTH_202007.csv')
subway_2008=pd.read_csv('./CARD_SUBWAY_MONTH_202008.csv')
subway_2009=pd.read_csv('./CARD_SUBWAY_MONTH_202009.csv')
subway_2010=pd.read_csv('./CARD_SUBWAY_MONTH_202010.csv')
subway_2011=pd.read_csv('./CARD_SUBWAY_MONTH_202011.csv')
subway_2012=pd.read_csv('./CARD_SUBWAY_MONTH_202012.csv')
subway_2101=pd.read_csv('./CARD_SUBWAY_MONTH_202101.csv')
subway_2102=pd.read_csv('./CARD_SUBWAY_MONTH_202102.csv')
subway_2103=pd.read_csv('./CARD_SUBWAY_MONTH_202103.csv')
subway_2104=pd.read_csv('./CARD_SUBWAY_MONTH_202104.csv')
subway_2105=pd.read_csv('./CARD_SUBWAY_MONTH_202105.csv')
subway_2106=pd.read_csv('./CARD_SUBWAY_MONTH_202106.csv')
subway_2107=pd.read_csv('./CARD_SUBWAY_MONTH_202107.csv')

# %%
# 수도권 지하철 일일 승하차 인원 수 데이터 전처리
subway_total=subway_1901
subway_total=subway_total.append(subway_1902)
subway_total=subway_total.append(subway_1903)
subway_total=subway_total.append(subway_1904)
subway_total=subway_total.append(subway_1905)
subway_total=subway_total.append(subway_1906)
subway_total=subway_total.append(subway_1907)
subway_total=subway_total.append(subway_1908)
subway_total=subway_total.append(subway_1909)
subway_total=subway_total.append(subway_1910)
subway_total=subway_total.append(subway_1911)
subway_total=subway_total.append(subway_1912)
subway_total=subway_total.append(subway_2001)
subway_total=subway_total.append(subway_2002)
subway_total=subway_total.append(subway_2003)
subway_total=subway_total.append(subway_2004)
subway_total=subway_total.append(subway_2005)
subway_total=subway_total.append(subway_2006)
subway_total=subway_total.append(subway_2007)
subway_total=subway_total.append(subway_2008)
subway_total=subway_total.append(subway_2009)
subway_total=subway_total.append(subway_2010)
subway_total=subway_total.append(subway_2011)
subway_total=subway_total.append(subway_2012)
subway_total=subway_total.append(subway_2101)
subway_total=subway_total.append(subway_2102)
subway_total=subway_total.append(subway_2103)
subway_total=subway_total.append(subway_2104)
subway_total=subway_total.append(subway_2105)
subway_total=subway_total.append(subway_2106)
subway_total=subway_total.append(subway_2107)

# %%
subway= subway_total.groupby(['date']).sum()
subway=subway.drop('reg_date', axis=1)
subway['total']=subway['on_num']+subway['off_num']

# %%
subway.to_csv('일별_승하차수_20190101~20210731.csv',index=True)

# %%
coro=corona_seoul[370:523]

# %%
coro=coro.reset_index()

# %%
len(corona_seoul[73:])
# Out:
# 482

# %%
corona_seoul[73:523]
# Out:
# date
# 2020-05-08     13
# 2020-05-09     18
# 2020-05-10     21
# 2020-05-11     11
# 2020-05-12      8
#              ...
# 2021-07-27    573
# 2021-07-28    514
# 2021-07-29    488
# 2021-07-30    475
# 2021-07-31    473
# Name: corona, Length: 450, dtype: int64

# %%
# 확진자 수와 탑승객 수 사이의 상관관계 구하기
corr_list=[]
for i in range():
    coro=coro_seoul
    coro=coro.reset_index()
    add_col=coro['corona'].values
    temp=subway[]
    subway['coro']=add_col
    corr=freq.corr()
    corr_list.append(corr['coro']['on_num'])
    subway= subway_total.groupby(['date']).sum()
    subway=subway.drop('reg_date', axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8856bbf8cbff> in <module>
#       5     coro=coro.reset_index()
#       6     add_col=coro['corona'].values
# ----> 7     subway['coro']=add_col
#       8     corr=freq.corr()
#       9     corr_list.append(corr['coro']['on_num'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...

# %%
corr_list
# Out:
# [0.07505949956423522,
#  0.07029934397175212,
#  0.04121066611976955,
#  0.02228830407786365,
#  0.008273904579583609,
#  0.047624400121850326,
#  0.09253638558114025,
#  0.09875186438513514,
#  0.043249971923566256,
#  0.03364675671409895,
#  -0.021940149454361978,
#  0.013620280506286,
#  0.02065258842001784,
#  0.014612157178223702,
#  0.05181640945072995,
#  0.06510826244865472,
#  0.021364441362385415,
#  0.0003123606612027782,
#  -0.04164509010624069,
#  -0.06912475033981949,
#  -0.07698430212754738,
#  -0.013028646367119437,
#  -0.0730121380464803,
#  -0.09353500393273147,
#  -0.09888981589536557,
#  -0.1365089508657309,
#  -0.19098779987970094,
#  -0.15031738453860993,
#  -0.12466149850436407,
#  -0.17984260634956833,
#  -0.17736252431989372,
#  -0.1643800870675288,
#  -0.2015762055596637,
#  -0.22050088783320154,
#  -0.19355693661344034,
#  -0.16652202795204057,
#  -0.23417075173043633,
#  -0.21410244284359825,
#  -0.21726876296440212,
#  -0.22697978625917933,
# ...

# %%
subway.index[493:]
# Out:
# Int64Index([20200508, 20200509, 20200510, 20200511, 20200512, 20200513,
#             20200514, 20200515, 20200516, 20200517,
#             ...
#             20210722, 20210723, 20210724, 20210725, 20210726, 20210727,
#             20210728, 20210729, 20210730, 20210731],
#            dtype='int64', name='date', length=450)

# %%
add_col=coro['corona'].values

# %%
x=list(range(-370,32))

# %%
len(x)
# Out:
# 402

# %%
type(add_col)
# Out:
# numpy.ndarray

# %%
freq['coro']=add_col

# %%
freq.head(10)
# Out:
#            on_num  off_num  coro
# date
# 20210301  2635986  2623335   131
# 20210302  6408282  6387540   120
# 20210303  6520055  6499138    92
# 20210304  6499933  6480614   120
# 20210305  6861445  6840754   118
# 20210306  4546437  4527195   118
# 20210307  3243833  3226505   131
# 20210308  6462083  6440106   127
# 20210309  6578984  6558465   131
# 20210310  6637015  6617534   100

# %%
corr=freq.corr()

# %%
corr
# Out:
#            on_num   off_num
# on_num   1.000000  0.999999
# off_num  0.999999  1.000000

# %%
corr['coro']

# %%
freq.describe()
# Out:
#              on_num       off_num        coro
# count  1.530000e+02  1.530000e+02  153.000000
# mean   5.703459e+06  5.683989e+06  238.509804
# std    1.374222e+06  1.373059e+06  131.773186
# min    2.420437e+06  2.407302e+06   79.000000
# 25%    4.625339e+06  4.604009e+06  141.000000
# 50%    6.517229e+06  6.499138e+06  201.000000
# 75%    6.701750e+06  6.682233e+06  257.000000
# max    7.107360e+06  7.082374e+06  637.000000

# %%
# 날짜 변동에 따른 확진자 수와 탑승객 간의 상관관계 시각화
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.title('날짜 변동에 따른 확진자 수와 지하철 탑승객 수 사이의 상관관계')
plt.xlabel('date_shift')
plt.ylabel('corr')
plt.plot(x,corr_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-d2ab7e3d130b> in <module>
#       9 plt.xlabel('date_shift')
#      10 plt.ylabel('corr')
# ---> 11 plt.plot(x,corr_list)
#
# NameError: name 'x' is not defined

# %%
x=[]
for i in range(0,943,7):
    temp=freq['total'][i:i+7].sum()
    x.append(temp)

# %%
len(x)
# Out:
# 135

# %%
import datetime as dt
from datetime import timedelta as td

# %%
d=dt.datetime(2020,5,8)+td(days=481)
d
# Out:
# datetime.datetime(2021, 9, 1, 0, 0)

# %%
weeks=[]
for i in range(0,943,7):
    d=dt.datetime(2020,5,8)+td(days=i)
    weeks.append(d.strftime('%Y-%m-%d'))

# %%
subway
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-08fc37bfd3d3> in <module>
# ----> 1 subway
#
# NameError: name 'subway' is not defined

# %%
len(weeks)
# Out:
# 135

# %%
y=[80000000]*135

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.title('2019년1월부터 2021년7월까지 월간 코로나 확진자수와 지하철 탑승자 수')
plt.xlabel('month')
plt.ylabel('')
plt.plot(weeks,x,)

# %%
weeks
# Out:
# ['2019-01-01',
#  '2019-01-08',
#  '2019-01-15',
#  '2019-01-22',
#  '2019-01-29',
#  '2019-02-05',
#  '2019-02-12',
#  '2019-02-19',
#  '2019-02-26',
#  '2019-03-05',
#  '2019-03-12',
#  '2019-03-19',
#  '2019-03-26',
#  '2019-04-02',
#  '2019-04-09',
#  '2019-04-16',
#  '2019-04-23',
#  '2019-04-30',
#  '2019-05-07',
#  '2019-05-14',
#  '2019-05-21',
#  '2019-05-28',
#  '2019-06-04',
#  '2019-06-11',
#  '2019-06-18',
#  '2019-06-25',
#  '2019-07-02',
#  '2019-07-09',
#  '2019-07-16',
#  '2019-07-23',
#  '2019-07-30',
#  '2019-08-06',
#  '2019-08-13',
#  '2019-08-20',
#  '2019-08-27',
#  '2019-09-03',
#  '2019-09-10',
#  '2019-09-17',
#  '2019-09-24',
#  '2019-10-01',
#  '2019-10-08',
#  '2019-10-15',
#  '2019-10-22',
#  '2019-10-29',
#  '2019-11-05',
#  '2019-11-12',
#  '2019-11-19',
#  '2019-11-26',
#  '2019-12-03',
#  '2019-12-10',
#  '2019-12-17',
#  '2019-12-24',
#  '2019-12-31',
#  '2020-01-07',
#  '2020-01-14',
#  '2020-01-21',
#  '2020-01-28',
#  '2020-02-04',
# ...

# %%
coro=coro_seoul
coro=coro.reset_index()
add_col=coro['corona'].values
subway_temp=subway.drop(list(subway.index[:493]))
subway_temp['coro']=add_col
corr=subway_temp.corr()
corr_list.append(corr['coro']['on_num'])
corr
# Out:
#            on_num   off_num     total      coro
# on_num   1.000000  0.999998  1.000000 -0.054297
# off_num  0.999998  1.000000  1.000000 -0.054192
# total    1.000000  1.000000  1.000000 -0.054244
# coro    -0.054297 -0.054192 -0.054244  1.000000

# %%
list(subway.index[:493])
# Out:
# [20190101,
#  20190102,
#  20190103,
#  20190104,
#  20190105,
#  20190106,
#  20190107,
#  20190108,
#  20190109,
#  20190110,
#  20190111,
#  20190112,
#  20190113,
#  20190114,
#  20190115,
#  20190116,
#  20190117,
#  20190118,
#  20190119,
#  20190120,
#  20190121,
#  20190122,
#  20190123,
#  20190124,
#  20190125,
#  20190126,
#  20190127,
#  20190128,
#  20190129,
#  20190130,
#  20190131,
#  20190201,
#  20190202,
#  20190203,
#  20190204,
#  20190205,
#  20190206,
#  20190207,
#  20190208,
#  20190209,
#  20190210,
#  20190211,
#  20190212,
#  20190213,
#  20190214,
#  20190215,
#  20190216,
#  20190217,
#  20190218,
#  20190219,
#  20190220,
#  20190221,
#  20190222,
#  20190223,
#  20190224,
#  20190225,
#  20190226,
#  20190227,
#  20190228,
#  20190301,
#  20190302,
#  20190303,
#  20190304,
#  20190305,
#  20190306,
#  20190307,
#  20190308,
#  20190309,
#  20190310,
#  20190311,
#  20190312,
#  20190313,
#  20190314,
#  20190315,
#  20190316,
#  20190317,
# ...

# %%
subway_temp=subway.drop(list(subway.index[:493]))

# %%
subway_temp
# Out:
#            on_num  off_num     total
# date
# 20200508  6803596  6781426  13585022
# 20200509  3831773  3816818   7648591
# 20200510  3077311  3061523   6138834
# 20200511  6399354  6380908  12780262
# 20200512  6350364  6332464  12682828
# ...           ...      ...       ...
# 20210727  5593883  5577147  11171030
# 20210728  5569642  5552971  11122613
# 20210729  5516631  5499607  11016238
# 20210730  5632486  5615478  11247964
# 20210731  3420215  3405347   6825562
#
# [450 rows x 3 columns]

# %%
len(coro['corona'].values)
# Out:
# 450
